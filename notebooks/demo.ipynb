# %% [markdown]
# # Notebook extensions

# %%
# %%capture
# %load_ext autoreload
# %autoreload 2
# %load_ext kedro.ipython

# %%
catalog.load('parameters')
# Out:
#                     INFO     Loading data from parameters (MemoryDataset)...                    ]8;id=231274;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=5780;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {
#     'split_parameters': {'test_size': 0.15, 'random_state': 3},
#     'features': [
#         'engines',
#         'passenger_capacity',
#         'crew',
#         'd_check_complete',
#         'moon_clearance_complete',
#         'iata_approved',
#         'company_rating',
#         'review_scores_rating'
#     ],
#     'model_params': {'fit_intercept': True},
#     'target_column': 'price'
# }

# %% [markdown]
# # Imports

# %%
import pandas as pd

# %% [markdown]
# # Dataset wrapper

# %%
catalog.load("shuttles").head(3)
# Out:
#                     INFO     Loading data from shuttles (ExcelDataset)...                       ]8;id=708872;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=598632;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  45163  Sao Tome and Principe      Type V5      Plasma  ThetaBase Services
# 1  49438      Wallis and Futuna      Type V2      Plasma  ThetaBase Services
# 2  10750                   Niue      Type F5     Quantum  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew d_check_complete  \
# ...

# %%
companies_df = catalog.load("companies")
type(companies_df)
# Out:
# [02/12/25 18:10:56] INFO     Loading data from companies (CSVDataset)...                        ]8;id=219457;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=167048;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <class 'pandas.core.frame.DataFrame'>

# %%
companies_df.head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id company_rating        company_location  total_fleet_count  \
# 0   3888           100%             Isle of Man                1.0
# 1  46728           100%                     NaN                1.0
# 2  34618            38%             Isle of Man                1.0
# 3  28619           100%  Bosnia and Herzegovina                1.0
# 4   8240            NaN                   Chile                1.0
#
#   iata_approved
# 0             f
# 1             f
# 2             f
# 3             f
# 4             t

# %%
companies_df['iata_approved'].value_counts(dropna=False)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# iata_approved
# f      6001
# t      4016
# NaN       2
# Name: count, dtype: int64

# %%
pd.read_csv('../data/01_raw/companies.csv').head()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       id company_rating        company_location  total_fleet_count  \
# 0   3888           100%             Isle of Man                1.0
# 1  46728           100%                     NaN                1.0
# 2  34618            38%             Isle of Man                1.0
# 3  28619           100%  Bosnia and Herzegovina                1.0
# 4   8240            NaN                   Chile                1.0
#
#   iata_approved
# 0             f
# 1             f
# 2             f
# 3             f
# 4             t

# %% [markdown]
# Clear that Kedro catalog just wraps common libraries, for example, pandas

# %% [markdown]
# # Check any dataset
#
# Apart from the source tables, we can take any intermediate dataset if it's persisted

# %%
catalog.load("model_input_features")
# Out:
#                     INFO     Loading data from model_input_features (ParquetDataset)...         ]8;id=939682;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=323425;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       engines  passenger_capacity  crew  d_check_complete  \
# 0         1.0                   2   1.0              True
# 1         1.0                   1   0.0              True
# 2         1.0                   2   1.0             False
# 3         1.0                   2   0.0              True
# 4         1.0                   4   2.0              True
# ...       ...                 ...   ...               ...
# ...

# %% [markdown]
# # Check scaler

# %%
scaler = catalog.load("fitted_scaler")
scaler
# Out:
#                     INFO     Loading data from fitted_scaler (PickleDataset)...                 ]8;id=688755;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=249234;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# MinMaxScaler()

# %%
type(scaler)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <class 'sklearn.preprocessing._data.MinMaxScaler'>

# %%
scaler.feature_names_in_
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# array(['engines', 'passenger_capacity', 'crew', 'company_rating',
#        'review_scores_rating'], dtype=object)

# %%
scaler.data_min_, scaler.data_max_
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# (array([ 0.,  1.,  0.,  0., 20.]), array([  7.,  20.,  16.,   1., 100.]))

# %%
scaler.n_samples_seen_
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 5114

# %% [markdown]
# # Check model
# This may be even a model - Kedro takes care of serialising and deserialising

# %%
regressor = catalog.load("regressor")
regressor
# Out:
#                     INFO     Loading data from regressor (PickleDataset)...                     ]8;id=210510;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=69605;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# LinearRegression()

# %%
regressor.get_params()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': None, 'positive': False}

# %%
regressor.feature_names_in_
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# array(['engines', 'passenger_capacity', 'crew', 'd_check_complete',
#        'moon_clearance_complete', 'iata_approved', 'company_rating',
#        'review_scores_rating', 'engines_squared', 'engines_log',
#        'engines_sqrt', 'passenger_capacity_squared',
#        'passenger_capacity_log', 'passenger_capacity_sqrt',
#        'crew_squared', 'crew_log', 'crew_sqrt', 'company_rating_squared',
#        'company_rating_log', 'company_rating_sqrt',
#        'review_scores_rating_squared', 'review_scores_rating_log',
#        'review_scores_rating_sqrt'], dtype=object)

# %%
coefficients_df = pd.DataFrame({
    'Feature': regressor.feature_names_in_,
    'Coefficient': regressor.coef_[0]
})
coefficients_df["Coefficient"] = coefficients_df["Coefficient"].round(4)
coefficients_df
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                          Feature  Coefficient
# 0                        engines   -3587.3645
# 1             passenger_capacity    3911.1552
# 2                           crew    4648.7955
# 3               d_check_complete     -55.3552
# 4        moon_clearance_complete      -0.0000
# 5                  iata_approved      -4.1541
# 6                 company_rating   13394.8955
# 7           review_scores_rating  -21743.7680
# 8                engines_squared    3933.6753
# 9                    engines_log     438.7465
# 10                  engines_sqrt    2947.9165
# 11    passenger_capacity_squared     498.4271
# 12        passenger_capacity_log      37.3087
# 13       passenger_capacity_sqrt    1113.9429
# 14                  crew_squared   -6201.2153
# 15                      crew_log    -141.4409
# ...

# %% [markdown]
# # Nodes execution

# %%
spaceflight_primary_df = catalog.load("spaceflight_primary_table")
spaceflight_primary_df.head()
# Out:
#                     INFO     Loading data from spaceflight_primary_table (ParquetDataset)...    ]8;id=378520;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=573537;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#         shuttle_location shuttle_type engine_type       engine_vendor  \
# 0                 Guinea      Type V5      Plasma  ThetaBase Services
# 1  Sao Tome and Principe      Type F5      Plasma  ThetaBase Services
# 2     Russian Federation      Type V5      Plasma  ThetaBase Services
# 3  Sao Tome and Principe      Type V5      Plasma  ThetaBase Services
# 4     Russian Federation      Type V5     Quantum  ThetaBase Services
#
# ...

# %%
from kedro_mlflow_tutorial.pipelines.ml_app.pipeline import create_preprocessing_pipeline

# %%
preprocessing_pipeline = create_preprocessing_pipeline()
preprocessing_pipeline.nodes
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     Node(extract_target, ['spaceflight_primary_table', 'params:target_column'], 'model_input_target', 'extract_target_node'),
#     Node(split_data, ['spaceflight_primary_table', 'model_input_target', 'params:split_parameters'], ['X_train_raw', 'X_test_raw', 'y_train', 'y_test'], 'split_data_node'),
#     Node(select_training_columns, ['X_test_raw', 'params:features'], 'X_test', 'select_test_columns_node'),
#     Node(select_training_columns, ['X_train_raw', 'params:features'], 'X_train', 'select_train_columns_node'),
#     Node(fit_numerical_features_scaler, 'X_train', 'fitted_scaler', 'fit_numerical_scaler_node'),
#     Node(transform_numerical_features, ['X_test', 'fitted_scaler'], 'X_test_scaled', 'transform_test_node'),
#     Node(transform_numerical_features, ['X_train', 'fitted_scaler'], 'X_train_scaled', 'transform_train_node'),
# ...

# %%
preprocessing_pipeline.nodes[2]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Node(select_training_columns, ['X_test_raw', 'params:features'], 'X_test', 'select_test_columns_node')

# %%
catalog.load('parameters')['features']
# Out:
#                     INFO     Loading data from parameters (MemoryDataset)...                    ]8;id=566335;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=775615;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# [
#     'engines',
#     'passenger_capacity',
#     'crew',
#     'd_check_complete',
#     'moon_clearance_complete',
#     'iata_approved',
#     'company_rating',
#     'review_scores_rating'
# ]

# %%
preprocessing_pipeline.nodes[2].func
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <function select_training_columns at 0x1459c56c0>

# %%
preprocessing_pipeline.nodes[2].func(catalog.load("spaceflight_primary_table"), catalog.load('parameters')['features'])
# Out:
# [02/12/25 18:10:57] INFO     Loading data from spaceflight_primary_table (ParquetDataset)...    ]8;id=383110;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=606178;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
#                     INFO     Loading data from parameters (MemoryDataset)...                    ]8;id=376637;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=372798;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...

# %%
from kedro_mlflow_tutorial.pipelines.ml_app.nodes import select_training_columns

select_training_columns(spaceflight_primary_df, catalog.load('parameters')['features'])
# Out:
# [02/10/25 21:35:33] INFO     Loading data from parameters (MemoryDataset)...                    ]8;id=933150;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=555439;file:///Users/Oleg_Litvinov1/Documents/Code/kedro_mlflow_tutorial/.venv/lib/python3.12/site-packages/kedro/io/data_catalog.py#389\389]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#       engines  passenger_capacity  crew  d_check_complete  \
# 0         1.0                   4   2.0             False
# 1         3.0                   6   3.0             False
# 2         1.0                   2   1.0             False
# 3         2.0                   5   4.0             False
# 4         1.0                   2   1.0              True
# ...       ...                 ...   ...               ...
# ...

# %% [markdown]
# the output is exactly the same
